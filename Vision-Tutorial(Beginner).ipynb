# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.PETS)
path.ls()
# Out:
# (#2) [Path('/home/emmy/.fastai/data/oxford-iiit-pet/annotations'),Path('/home/emmy/.fastai/data/oxford-iiit-pet/images')]

# %%
files = get_image_files(path/"images")
len(files)
# Out:
# 7390

# %%
files[0], files[6]
# Out:
# (Path('/home/emmy/.fastai/data/oxford-iiit-pet/images/japanese_chin_150.jpg'),
#  Path('/home/emmy/.fastai/data/oxford-iiit-pet/images/Sphynx_144.jpg'))

# %%
def label_func(f): return f[0].isupper()

# %%
dls = ImageDataLoaders.from_name_func(path, files, label_func, item_tfms=Resize(224))

# %%
dls.show_batch()

# %%
learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.predict(files[0])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('True', TensorBase(1), TensorBase([0.0689, 0.9311]))

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
files[1].name
pat = r'^(.*)_'
dls = ImageDataLoaders.from_name_re(path, files, pat, item_tfms=Resize(224))

# %%
dls.show_batch()
